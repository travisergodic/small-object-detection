# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/
# !unzip /content/gdrive/MyDrive/2-專案/玉山-無人飛行載具計數/資料/coco.zip
# !unzip /content/gdrive/MyDrive/2-專案/玉山-無人飛行載具計數/資料/slice_coco_600_624_0.25_0.25.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0811_900_456_1500_1080.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0431_0_0_600_624.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0266_900_0_1500_624.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0187_450_0_1050_624.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0645_450_0_1050_624.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0865_0_0_600_624.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0205_1320_0_1920_624.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0279_450_456_1050_1080.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0440_1320_0_1920_624.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0670_0_456_600_1080.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0595_1320_0_1920_624.jpg
#   inflating: slice_coco_600_624_0.25_0.25/train2017/img0381_1320_0_1920_624.jpg
# ...

# %%
# !python -m pip install paddlepaddle-gpu==2.4.1.post116 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# !pip install pycocotools
# !git clone https://github.com/PaddlePaddle/PaddleYOLO  # clone
# %cd PaddleYOLO
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.4/567.4 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.2/383.2 kB 33.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# ...

# %%
# %cd /content/PaddleYOLO
# !python tools/infer.py -c /content/PaddleYOLO/configs/smalldet/ppyoloe_crn_l_80e_sliced_visdrone_640_025.yml\
                       -o weights=/content/gdrive/MyDrive/2-專案/玉山-無人飛行載具計數/model/ppyoloe_600_624_0.25_0.25/best_model.pdparams \
                       --infer_img=/content/coco_t/val2017/img0007.png \
                        --draw_threshold=0.25
# Out:
# /content/PaddleYOLO
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# ...

# %%
# !pip install sahi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=12e6b4ed710d127b26a592f03bb508e7d0a496f764bec45abb8f6f591f14e74e
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
# %cd /content/PaddleYOLO

# !python tools/infer.py -c /content/PaddleYOLO/configs/smalldet/ppyoloe_crn_l_80e_sliced_visdrone_640_025.yml\
                       -o weights=/content/gdrive/MyDrive/2-專案/玉山-無人飛行載具計數/model/ppyoloe_600_624_0.25_0.25/best_model.pdparams\
                       --infer_img=/content/coco_t/val2017/img0007.png \
                       --draw_threshold=0.25 \
                       --slice_infer \
                       --slice_size 624 600 --overlap_ratio 0.25 0.25 \
                       --combine_method=nms --match_threshold=0.6 --match_metric=ios
# Out:
# /content/PaddleYOLO
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# ...
